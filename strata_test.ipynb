# %%
from lifelines import CoxPHFitter
import pandas as pd

df = pd.DataFrame(
    {
        "T": [5, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
        "E": [1, 1, 1, 1, 1, 1, 0, 0, 1, 1, 1, 0],
        "var": [0, 0, 0, 0, 1, 1, 1, 1, 1, 2, 2, 2],
        "weights": [1.1, 0.5, 2.0, 1.6, 1.2, 4.3, 1.4, 4.5, 3.0, 3.2, 0.4, 6.2],
        "month": [10, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
        "age": [4, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
    }
)

cph = CoxPHFitter()
cph.fit(df, "T", "E", strata=["month", "age"], robust=True, weights_col="weights")
cph.print_summary()
# Out:
# c:\Users\user\SURVIVAL\surv_env\Lib\site-packages\lifelines\fitters\coxph_fitter.py:1607: ConvergenceWarning: Newton-Raphson convergence completed successfully but norm(delta) is still high, 0.793. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
#
#   warnings.warn(
# <lifelines.CoxPHFitter: fitted with 29.4 total observations, 12.1 right-censored observations>
#              duration col = 'T'
#                 event col = 'E'
#               weights col = 'weights'
#           robust variance = True
#                    strata = ['month', 'age']
#       baseline estimation = breslow
#    number of observations = 29.4
# number of events observed = 17.3
#    partial log-likelihood = -16.25
#          time fit was run = 2024-12-25 09:56:28 UTC
#
# ---
#             coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# var       -18.44      0.00      0.00          -18.44          -18.44                0.00                0.00
#
#            cmp to    z      p  -log2(p)
# covariate
# var          0.00 -inf <0.005       inf
# ---
# Concordance = 0.83
# Partial AIC = 34.50
# log-likelihood ratio test = 6.67 on 1 df
# -log2(p) of ll-ratio test = 6.67

# %%
df
# Out:
#     T  E  var  weights  month  age
# 0   5  1    0      1.1     10    4
# 1   3  1    0      0.5      3    3
# 2   9  1    0      2.0      9    9
# 3   8  1    0      1.6      8    8
# 4   7  1    1      1.2      7    7
# 5   4  1    1      4.3      4    4
# 6   4  0    1      1.4      4    4
# 7   3  0    1      4.5      3    3
# 8   2  1    1      3.0      2    2
# 9   5  1    2      3.2      5    5
# 10  6  1    2      0.4      6    6
# 11  7  0    2      6.2      7    7

# %%
from lifelines import CoxPHFitter
import pandas as pd


cph = CoxPHFitter()
cph.add_frailty(group_col="group_col_name", distribution="gamma")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       2 import pandas as pd
#       5 cph = CoxPHFitter()
# ----> 6 cph.add_frailty(group_col="group_col_name", distribution="gamma")
#
# File c:\Users\user\SURVIVAL\surv_env\Lib\site-packages\lifelines\fitters\coxph_fitter.py:594, in CoxPHFitter.__getattr__(self, attr)
#     591 if attr == "_model":
#     592     raise AttributeError("Must call `fit` first.")
# --> 594 if hasattr(self._model, attr):
#     595     return getattr(self._model, attr)
#     597 raise AttributeError("%s has no attribute '%s'" % (self._class_name, attr))
#
# File c:\Users\user\SURVIVAL\surv_env\Lib\site-packages\lifelines\fitters\coxph_fitter.py:592, in CoxPHFitter.__getattr__(self, attr)
#     590 def __getattr__(self, attr):
#     591     if attr == "_model":
# --> 592         raise AttributeError("Must call `fit` first.")
#     594     if hasattr(self._model, attr):
#     595         return getattr(self._model, attr)
#
# AttributeError: Must call `fit` first.
