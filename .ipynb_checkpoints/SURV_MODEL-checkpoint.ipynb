# %%
import lifelines
import pandas as pd
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt
import numpy as np
from lifelines import *
from lifelines.utils import median_survival_times

# %%
main_path = "C:/Users/user/Desktop/DISEASE/"
data_name = 'stomach.csv'

# %%
df = pd.read_csv(main_path+data_name, index_col=0)
df.head()
# Out:
#    SERIAL_ID  sex  age icd_10  seercode  event_inc  stime  tx_1  tx_2  tx_3  \
# 0        142    1   59   C163       3.0          1      0     0     0     0
# 1        142    1   59   C163       3.0          1      0     0     0     0
# 2        328    2   72   C160       2.0          1      0     0     0     0
# 3        365    1   41   C161       3.0          1    160     1     0     1
# 4        478    1   59   C163       1.0          1    168     1     0     0
#
#    tx_4  tx_5  seer_TF
# 0     0     0        1
# 1     0     0        1
# 2     0     0        1
# 3     0     0        1
# 4     0     0        0

# %%
T = df['stime']
E = df['event_inc']

kmf = KaplanMeierFitter()
kmf.fit(T, event_observed=E)
# Out:
# <lifelines.KaplanMeierFitter:"KM_estimate", fitted with 41556 total observations, 24417 right-censored observations>

# %%
kmf.survival_function_
kmf.cumulative_density_
kmf.plot_survival_function(ci_show=True)
# Out:
# <AxesSubplot:xlabel='timeline'>

# %%
kmf.plot_cumulative_density(ci_show=True)
# Out:
# <AxesSubplot:xlabel='timeline'>

# %% [markdown]
# ## 전이 유무로 구분해서 KMF fitting

# %%
# 한글 폰트 설정
from matplotlib import rc
plt.rc('font', family='NanumGothic')

ax = plt.subplot(111)

seer_tf = (df['seer_TF'] == 1)

kmf.fit(T[seer_tf], event_observed =E[seer_tf], label ='전이가 된 환자들')
kmf.plot_survival_function(ax=ax)

kmf.fit(T[~seer_tf], event_observed = E[~seer_tf], label = '전이가 되지 않은 환자들')
kmf.plot_survival_function(ax=ax)

plt.title('lifespans of patients whose cancer is metastasized ');

# %%
# import matplotlib
# import lifelines

# print(lifelines.__version__)
# print(matplotlib.__version__)
# Out:
# 0.30.0
# 3.9.2

# %% [markdown]
# ## Duration 을 정규화

# %%
kmf.fit(T,E, timeline=range(0,100,2))
kmf.survival_function_
kmf.confidence_interval_

median_ = kmf.median_survival_time_
median_confidence_interval_ = median_survival_times(kmf.confidence_interval_)

# %%
df.head()
# Out:
#    sex  age icd_10 seercode  event  stime  mcode2  tx_1  tx_2  tx_3  tx_4  \
# 0    1   78   C169      NaN      1      9       3     0     0     0     0
# 1    2   56   C166      NaN      1     16       3     0     1     1     0
# 2    1   50   C169      NaN      0    300       3     0     0     0     0
# 3    1   50   C169      NaN      0    300       3     0     0     0     0
# 4    1   50   C169      NaN      0    300       3     0     0     0     0
#
#    tx_5
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# ## 다양한 생존함수를 적용 - 생존함수
